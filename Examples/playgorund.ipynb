# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/rcpsilva/MLBenchmarks/main/MLBenchmarks/datasets/Regression/spm%2Bdemagnetization/Dataset_SPM_demagnetization.csv')

# %%
df
# Out:
#           T_spec  Rated_speed_spec       Bmr         delta         m  \
# 0      90.997916       5116.643283  0.487506  39397.195441  1.975955
# 1      96.830847       2226.239955  1.117701  37152.332847  1.574790
# 2     102.586168       2589.833840  0.818783  18766.047877  2.104074
# 3     111.253693       3163.692510  0.528683  22063.089337  2.163076
# 4     172.367321       4311.028350  0.949390  33858.425728  1.570513
# ...          ...               ...       ...           ...       ...
# 6995  159.364113       4749.542270  1.039289  19504.290289  2.030319
# 6996  224.651212       2015.725351  0.754173  30060.974368  1.730464
# 6997   76.494218       4256.312308  0.833625  19827.664635  1.431976
# 6998  137.636142       4606.793403  1.094727  21790.744279  2.204684
# 6999  128.671616       2164.505874  0.813261  29548.179826  1.809786
#
#             so        d0     Lmagn        h4        h3  max_OL  \
# 0     0.006290  0.000851  0.512480  0.001664  0.003630       0
# 1     0.003757  0.001497  8.219508  0.001791  0.003028      11
# 2     0.006557  0.001192  1.988612  0.001773  0.003840       3
# 3     0.006596  0.001263  0.867449  0.001629  0.002692       0
# 4     0.004287  0.001406  3.652513  0.002261  0.002335       3
# ...        ...       ...       ...       ...       ...     ...
# 6995  0.004891  0.001188  4.427485  0.001844  0.002757       8
# 6996  0.004976  0.000800  1.090370  0.001866  0.002935       0
# 6997  0.004543  0.001574  2.753413  0.002411  0.003848       5
# 6998  0.003779  0.001432  6.948240  0.002315  0.003591      11
# 6999  0.006381  0.000872  1.429579  0.001422  0.002403       1
#
#       max_OL_analytical
# 0              1.149800
# 1             13.160608
# 2              3.702697
# 3              0.036690
# 4              3.615744
# ...                 ...
# 6995           9.063788
# 6996           0.377823
# 6997           5.538668
# 6998          15.631949
# 6999           0.687960
#
# [7000 rows x 12 columns]

# %%
data = df.to_numpy()[:,0:-2]

# %%
data[0]
# Out:
# array([9.09979155e+01, 5.11664328e+03, 4.87505920e-01, 3.93971954e+04,
#        1.97595483e+00, 6.29043147e-03, 8.50926110e-04, 5.12480129e-01,
#        1.66381856e-03, 3.63014381e-03])

# %%
target = df['max_OL_analytical'].to_numpy()

# %%
target
# Out:
# array([ 1.14980036, 13.16060767,  3.70269683, ...,  5.53866841,
#        15.63194932,  0.68795955])
